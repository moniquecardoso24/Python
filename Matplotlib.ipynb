# %% [markdown]
# # Matplotlib Exercices

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# Initializing list
valores = [1, 2, 3, 4, 5]
quadrados = [valores ** 2 for valores in valores]
cubos = [valores ** 3 for valores in valores]

# Converting list to array
quadrados2 = np.array(quadrados)
cubos2 = np.array(cubos)

# %%
# Showing the graphic

plt.plot(quadrados2)
plt.plot(cubos2)

# %%
# Showing the graphic

plt.plot(quadrados2, color = 'red', linewidth = '4', label = 'quadrados')
plt.plot(cubos2, color = 'green', linewidth = '4', label = 'cubos')

plt.legend()  #show legends

# Label 
plt.title("Valores elevado ao quadrado e cubo")
plt.xlabel("Valores", fontsize=15)
plt.ylabel("Quadrados", fontsize=15)
# Out:
# Text(0, 0.5, 'Quadrados')

# %%
# Initializing list

bandas = ['Metallica', 'Slayer', 'Megadeth']
albuns = [10, 11, 15]

# %%
# Bar graphic

#x-> bandas
#y -> albuns

plt.bar(bandas, albuns, color='green')
plt.title("Albuns de Estudio")
plt.xlabel("Banda", fontsize=14)
plt.ylabel("Quantidade de albuns", fontsize=14)
# Out:
# Text(0, 0.5, 'Quantidade de albuns')

# %%
# Scatterplots

dados_x = np.random.rand(1, 60)
dados_y = np.random.rand(1, 60)
tamanhos = np.random.rand(200, 1000)

# %%
# Showing the scatterplots

# s - modify the side of the bubbles
# alpha = add transparency effect

plt.scatter(dados_x, dados_y, color='pink', s=600, alpha=0.5)

# %%
# Histogram

dados = np.random.randn(600)
plt.hist(dados)

plt.hist(dados, color='orange')

plt.show()
